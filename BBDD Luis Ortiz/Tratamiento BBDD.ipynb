# %% [markdown]
# Importamos las librería necesarias

# %%
import pandas as pd

# %% [markdown]
# Cargamos el archivo que contiene la BBDD .csv y lo convertimos en df

# %%
path = './'
file_csv = 'BBDD Usuarios examenes preventivos.csv'

usuarios = pd.read_csv(path + file_csv)

usuarios
# Out:
#         Marca temporal                                Protección de Datos  \
# 0   23/2/2023 10:32:32  Acepto la política de privacidad y los término...
# 1   23/2/2023 11:27:34  Acepto la política de privacidad y los término...
# 2   24/2/2023 13:43:01  Acepto la política de privacidad y los término...
# 3    26/2/2023 0:07:13  Acepto la política de privacidad y los término...
# 4     2/3/2023 8:36:06  Acepto la política de privacidad y los término...
# ..                 ...                                                ...
# 65   8/2/2024 21:56:18  Acepto la política de privacidad y términos y ...
# 66  13/2/2024 11:40:27  Acepto la política de privacidad y términos y ...
# 67  16/2/2024 20:50:12  Acepto la política de privacidad y términos y ...
# 68  17/2/2024 16:42:18  Acepto la política de privacidad y términos y ...
# 69  21/2/2024 19:37:23  Acepto la política de privacidad y términos y ...
#
#    ¿Tiene alguna enfermedad crónica?  \
# 0                                 Sí
# ...

# %% [markdown]
# Convertimos el archivo en Excel

# %%
file_xlsx = 'BBDD Usuarios examenes preventivos.xlsx'
usuarios.to_excel(file_xlsx, index=False)

# %% [markdown]
# Contamos las variables NaN por columna

# %%
usuarios.isnull().sum(axis=0)
# Out:
# Marca temporal                                                                                  0
# Protección de Datos                                                                             0
# ¿Tiene alguna enfermedad crónica?                                                               0
# ¿Cuáles son sus patologías crónicas?                                                           42
# ¿Lo han operado alguna vez?                                                                     0
# ¿Qué cirugías le han realizado?                                                                23
# ¿Consume alcohol a diario o consume en exceso los fines de semana?                              2
# ¿Cuántas unidades de alcohol consume en promedio a la semana?                                  55
# ¿Actualmente fuma o ha fumado dentro de los últimos 10 años?                                    0
# ¿Cuántos cigarros en promedio fuma al día?                                                     52
# ...
